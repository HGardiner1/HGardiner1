# %% [markdown]
# <a href="https://colab.research.google.com/github/HGardiner1/HGardiner1/blob/main/YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.
#
# Install both YOLOv8 and pip

# %%
# !nvidia-smi
import os
HOME = os.getcwd()
print(HOME)
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.2/235.7 GB disk)

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source= 'https://m.media-amazon.com/images/I/61t6k8PsbqL._AC_UF894,1000_QL80_.jpg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 107MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://m.media-amazon.com/images/I/61t6k8PsbqL._AC_UF894,1000_QL80_.jpg to '61t6k8PsbqL._AC_UF894,1000_QL80_.jpg'...
# 100% 27.9k/27.9k [00:00<00:00, 21.2MB/s]
# image 1/1 /content/61t6k8PsbqL._AC_UF894,1000_QL80_.jpg: 640x640 1 airplane, 7.9ms
# Speed: 13.9ms preprocess, 7.9ms inference, 773.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict2/hammer.jpg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://m.media-amazon.com/images/I/61t6k8PsbqL._AC_UF894,1000_QL80_.jpg', conf=0.25)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to '/content/yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 113MB/s]
# Downloading https://m.media-amazon.com/images/I/61t6k8PsbqL._AC_UF894,1000_QL80_.jpg to '61t6k8PsbqL._AC_UF894,1000_QL80_.jpg'...
# 100%|██████████| 27.9k/27.9k [00:00<00:00, 20.4MB/s]
# image 1/1 /content/datasets/61t6k8PsbqL._AC_UF894,1000_QL80_.jpg: 640x640 1 airplane, 24.7ms
# Speed: 16.5ms preprocess, 24.7ms inference, 905.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[6.6620e+00, 6.7930e-01, 8.8814e+02, 8.9998e+02]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.7271, 0.2907, 0.2846], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Testing
# Test your datasets here

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="k4LKyrw5HO0DzJDVLDTQ")
project = rf.workspace("object-detection-ctnhg").project("object-detection-urc-ds9co")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# /content/datasets
# Collecting roboflow
#   Downloading roboflow-1.1.51-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2024.12.14)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.1.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.55.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.1)
# Downloading roboflow-1.1.51-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.9 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: filetype, python-dotenv, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 python-dotenv-1.0.1 roboflow-1.1.51
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Object-Detection-URC-4 to yolov8:: 100%|██████████| 128818/128818 [00:02<00:00, 49566.50it/s]
# Extracting Dataset Version Zip to Object-Detection-URC-4 in yolov8:: 100%|██████████| 3742/3742 [00:00<00:00, 4996.74it/s]

# %% [markdown]
# ## Gaussian Blurring

# %%
import cv2
import os

folder_path = "datasets/Object-Detection-URC-4/test/images"
def apply_gaussian_blur(folder_path):
  if not os.path.exists(folder_path):
    print("Invalid File Path")
    return

  # Iterate through all testing images in the folder
  for file_name in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file_name)

    if not os.path.isfile(file_path):
      continue

    image = cv2.imread(file_path)
    if image is None:
      continue

    # Write Code for the Kernels here


    blurred_image = cv2.filter2D(image, )

    # Add each new blurred image into the same file
    blurred_file_path = os.path.join(folder_path, f"blurred_{file_name}")
    cv2.imwrite(blurred_file_path, blurred_image)

  print("Images have been processed")

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=20 imgsz=800 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.3.68 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Object-Detection-URC-4/data.yaml, epochs=20, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 116MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# Model summary: 225 layers, 11,136,374 parameters, 11,136,358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 390MB/s]
# AMP: checks passed ✅
# train: Scanning /content/datasets/Object-Detection-URC-4/train/labels... 1664 images, 112 backgrounds, 0 corrupt: 100% 1664/1664 [00:00<00:00, 2062.85it/s]
# train: New cache created: /content/datasets/Object-Detection-URC-4/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1436, len(boxes) = 1734. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.1 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Object-Detection-URC-4/valid/labels... 99 images, 2 backgrounds, 0 corrupt: 100% 99/99 [00:00<00:00, 888.21it/s]
# val: New cache created: /content/datasets/Object-Detection-URC-4/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 93, len(boxes) = 98. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      5.88G      0.888       1.79       1.21         23        800: 100% 104/104 [00:55<00:00,  1.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.04it/s]
#                    all         99         98      0.596       0.49      0.345      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      5.82G      1.127       1.22      1.321         33        800: 100% 104/104 [00:52<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.96it/s]
#                    all         99         98      0.367      0.523       0.36      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      5.84G        1.1       1.16      1.318         27        800: 100% 104/104 [00:52<00:00,  1.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.61it/s]
#                    all         99         98      0.637      0.573      0.599      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      5.84G      1.099      1.146      1.318         21        800: 100% 104/104 [00:52<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.59it/s]
#                    all         99         98      0.713      0.497       0.65      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      5.83G      1.061      1.019      1.286         26        800: 100% 104/104 [00:51<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.80it/s]
#                    all         99         98      0.681      0.641      0.688      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      5.83G     0.9804     0.9556      1.237         22        800: 100% 104/104 [00:51<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.31it/s]
#                    all         99         98      0.961       0.86      0.956      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      5.84G     0.9519     0.8741      1.223         32        800: 100% 104/104 [00:52<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.41it/s]
#                    all         99         98      0.515      0.541       0.55      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      5.84G     0.9353     0.8442      1.216         30        800: 100% 104/104 [00:52<00:00,  2.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.56it/s]
#                    all         99         98      0.879      0.884      0.991      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      5.84G     0.8558     0.7646      1.164         31        800: 100% 104/104 [00:51<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.53it/s]
#                    all         99         98      0.983      0.883      0.943      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      5.84G     0.8465     0.7274      1.159         35        800: 100% 104/104 [00:51<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.56it/s]
#                    all         99         98      0.978      0.872      0.954      0.777
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      5.84G     0.7818     0.6183      1.131         14        800: 100% 104/104 [00:52<00:00,  1.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.71it/s]
#                    all         99         98       0.93      0.986      0.986      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      5.84G     0.7289     0.5757      1.088         16        800: 100% 104/104 [00:49<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.45it/s]
#                    all         99         98      0.813      0.989      0.922      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      5.84G     0.7047     0.5191      1.068         18        800: 100% 104/104 [00:52<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.62it/s]
#                    all         99         98      0.986      0.889      0.964      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      5.84G     0.6796     0.5043      1.054         35        800: 100% 104/104 [00:51<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.84it/s]
#                    all         99         98      0.904      0.979      0.977      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      5.84G     0.6515      0.464       1.04         16        800: 100% 104/104 [00:51<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.50it/s]
#                    all         99         98      0.976      0.989      0.991      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      5.84G     0.6192     0.4398      1.015         37        800: 100% 104/104 [00:52<00:00,  2.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.90it/s]
#                    all         99         98      0.969      0.889      0.975      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      5.84G     0.5906     0.4091      1.006         16        800: 100% 104/104 [00:52<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.43it/s]
#                    all         99         98      0.977      0.981      0.993      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      5.84G     0.5676      0.386     0.9895         14        800: 100% 104/104 [00:51<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.87it/s]
#                    all         99         98      0.974      0.992      0.993      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      5.84G     0.5447     0.3701      0.972         16        800: 100% 104/104 [00:51<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.47it/s]
#                    all         99         98      0.981      0.993      0.993      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      5.84G     0.5247     0.3549      0.968         14        800: 100% 104/104 [00:51<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  2.57it/s]
#                    all         99         98       0.98      0.995      0.993      0.883
#
# 20 epochs completed in 0.307 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 22.5MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.12it/s]
#                    all         99         98      0.981      0.993      0.993      0.887
#                 Bottle         92         93      0.968      0.986      0.991      0.939
#                 Mallet          5          5      0.994          1      0.995      0.835
# Speed: 0.5ms preprocess, 7.9ms inference, 0.0ms loss, 7.2ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/val_batch2_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Object-Detection-URC-4/valid/labels.cache... 99 images, 2 backgrounds, 0 corrupt: 100% 99/99 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 93, len(boxes) = 98. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.82it/s]
#                    all         99         98      0.981      0.993      0.993      0.887
#                 Bottle         92         93      0.968      0.986      0.991      0.939
#                 Mallet          5          5      0.994          1      0.995      0.835
# Speed: 2.5ms preprocess, 17.5ms inference, 0.0ms loss, 8.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/102 /content/datasets/Object-Detection-URC-4/test/images/102_jpg.rf.5f17010c9797d078302a704cc6f2c99c.jpg: 800x800 1 Bottle, 22.8ms
# image 2/102 /content/datasets/Object-Detection-URC-4/test/images/128_jpg.rf.77d3e1549ac2b5380ed019e721f71573.jpg: 800x800 1 Bottle, 22.9ms
# image 3/102 /content/datasets/Object-Detection-URC-4/test/images/128_jpg.rf.b2daa3d2683ac6ab31ae499bf1d80edc.jpg: 800x800 1 Bottle, 22.8ms
# image 4/102 /content/datasets/Object-Detection-URC-4/test/images/12_jpg.rf.47c992a58533294b082528302bf6159a.jpg: 800x800 1 Bottle, 22.8ms
# image 5/102 /content/datasets/Object-Detection-URC-4/test/images/149_jpg.rf.e4c84e3863feb6a207e9019051a20458.jpg: 800x800 1 Bottle, 22.8ms
# image 6/102 /content/datasets/Object-Detection-URC-4/test/images/162_jpg.rf.522abd8a544fce3d2aee122ee13205cc.jpg: 800x800 1 Bottle, 22.8ms
# image 7/102 /content/datasets/Object-Detection-URC-4/test/images/163_jpg.rf.882f85db3d2f65b5fb86b09392dfdc8e.jpg: 800x800 1 Bottle, 22.8ms
# image 8/102 /content/datasets/Object-Detection-URC-4/test/images/167_jpg.rf.04d33286de2c46b2463ad84c8bf3e51c.jpg: 800x800 1 Bottle, 22.8ms
# image 9/102 /content/datasets/Object-Detection-URC-4/test/images/171_jpg.rf.734a8446d4510de1e374386a1cec9e2b.jpg: 800x800 1 Bottle, 14.9ms
# image 10/102 /content/datasets/Object-Detection-URC-4/test/images/174_jpg.rf.d557b4aeffb57a84b4b383575705619f.jpg: 800x800 1 Bottle, 14.9ms
# image 11/102 /content/datasets/Object-Detection-URC-4/test/images/175_jpg.rf.7221e33a4550bf9b6f6473588daace1e.jpg: 800x800 1 Bottle, 14.9ms
# image 12/102 /content/datasets/Object-Detection-URC-4/test/images/175_jpg.rf.765c8d440576f2c252ef492bb838440e.jpg: 800x800 1 Bottle, 14.9ms
# image 13/102 /content/datasets/Object-Detection-URC-4/test/images/178_jpg.rf.bae397329970a23a8bfa52d764f92852.jpg: 800x800 1 Bottle, 14.6ms
# image 14/102 /content/datasets/Object-Detection-URC-4/test/images/183_jpg.rf.84da342c6dbbd86104c67ceaa3f74346.jpg: 800x800 1 Bottle, 14.6ms
# image 15/102 /content/datasets/Object-Detection-URC-4/test/images/190_jpg.rf.24e40607688d0db0823e73bb2f2dcae8.jpg: 800x800 1 Bottle, 14.6ms
# image 16/102 /content/datasets/Object-Detection-URC-4/test/images/191_jpg.rf.052463be3524ad0530fee6ecfaea654f.jpg: 800x800 1 Bottle, 14.6ms
# image 17/102 /content/datasets/Object-Detection-URC-4/test/images/193_jpg.rf.a2bee05d280b6087eff1466a94ac6e72.jpg: 800x800 1 Bottle, 11.6ms
# image 18/102 /content/datasets/Object-Detection-URC-4/test/images/194_jpg.rf.e1e2586b8c4afc3a84c530029751f1ae.jpg: 800x800 1 Bottle, 11.3ms
# image 19/102 /content/datasets/Object-Detection-URC-4/test/images/19_jpg.rf.76f905736be11d6746e06afb7fb6d539.jpg: 800x800 1 Bottle, 11.2ms
# image 20/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle0_jpeg_jpg.rf.21e9d0562909532a6a5a90a12381320e.jpg: 800x800 1 Bottle, 11.4ms
# image 21/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle103_jpeg_jpg.rf.b441e77301adf3e13e6932ec2cba2568.jpg: 800x800 2 Bottles, 11.8ms
# image 22/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle106_jpeg_jpg.rf.620ea04b404cabab42b384a102f18532.jpg: 800x800 1 Bottle, 11.8ms
# image 23/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle111_jpeg_jpg.rf.056c101ab69c7c162746938aac511540.jpg: 800x800 1 Bottle, 12.0ms
# image 24/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle113_jpeg_jpg.rf.82f2e441b0b79c56bc26193ec1e17077.jpg: 800x800 1 Bottle, 12.4ms
# image 25/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle132_jpeg_jpg.rf.6787f8c76445f33a12838ec4d248ea6e.jpg: 800x800 1 Bottle, 11.4ms
# image 26/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle161_jpeg_jpg.rf.8e48a23e0a312666467404c7c6fda15f.jpg: 800x800 24 Bottles, 11.3ms
# image 27/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle164_jpeg_jpg.rf.abc0da25519330421be5bcbec72c8fb6.jpg: 800x800 (no detections), 11.2ms
# image 28/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle166_png_jpg.rf.822b80837d5fe45e85f6e629902ded43.jpg: 800x800 1 Bottle, 11.1ms
# image 29/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle174_jpeg_jpg.rf.e4288f639121323e79ac0a0eb2640f18.jpg: 800x800 2 Bottles, 11.1ms
# image 30/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle181_jpeg_jpg.rf.08ae3cd21fcd3ff1ff7a0592060706ac.jpg: 800x800 1 Bottle, 11.1ms
# image 31/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle193_jpeg_jpg.rf.6db9b4a73faa28a6d2fd2639dacf2752.jpg: 800x800 1 Bottle, 11.3ms
# image 32/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle200_jpeg_jpg.rf.2c6485368d5d88313f21560e873f182c.jpg: 800x800 1 Bottle, 11.3ms
# image 33/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle206_jpeg_jpg.rf.2006956d703b32ac8d2bd08af7680b9f.jpg: 800x800 1 Bottle, 11.3ms
# image 34/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle212_jpeg_jpg.rf.43b6ab19dc6336f9eb7b6ba8c5a5f50d.jpg: 800x800 1 Bottle, 11.4ms
# image 35/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle216_jpeg_jpg.rf.1e7e0403d6b446f29300f3db30566202.jpg: 800x800 1 Bottle, 11.5ms
# image 36/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle218_jpeg_jpg.rf.0c18691bce8e6e937b989050ae491ba3.jpg: 800x800 1 Bottle, 11.6ms
# image 37/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle243_jpeg_jpg.rf.a232e158376df42972469b064c5e06af.jpg: 800x800 1 Bottle, 11.6ms
# image 38/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle266_png_jpg.rf.ff0240111838da5ffd8637b8cb471736.jpg: 800x800 1 Bottle, 11.5ms
# image 39/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle26_jpeg_jpg.rf.d6746756bc73eea5b62cbe1a7a3bbd7c.jpg: 800x800 1 Bottle, 11.5ms
# image 40/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle31_jpeg_jpg.rf.443f00bb204b8d06e2138c7059df68ec.jpg: 800x800 1 Bottle, 11.6ms
# image 41/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle32_jpeg_jpg.rf.4adf9c7c01479541c085e6bfb5aaf7cf.jpg: 800x800 1 Bottle, 11.7ms
# image 42/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle32_jpeg_jpg.rf.6c394e47832a7751cbda2a5104f06bcb.jpg: 800x800 1 Bottle, 11.7ms
# image 43/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle54_jpeg_jpg.rf.1ebb726d00b7099610eb9177a6c34497.jpg: 800x800 1 Bottle, 11.6ms
# image 44/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle58_jpeg_jpg.rf.d4f82a1623ca73ec4cdf8cef5a8db9be.jpg: 800x800 1 Bottle, 11.6ms
# image 45/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle76_jpeg_jpg.rf.f03af053aaac677183d8c76f43eb8e67.jpg: 800x800 1 Bottle, 11.5ms
# image 46/102 /content/datasets/Object-Detection-URC-4/test/images/1literwidemouthwaterbottle81_jpeg_jpg.rf.74483a52613700ea8eebe4f0f8bb0758.jpg: 800x800 4 Bottles, 11.4ms
# image 47/102 /content/datasets/Object-Detection-URC-4/test/images/20231031_222555_jpg.rf.e327f359be84bfe2663c090b7931e5d8.jpg: 800x800 (no detections), 11.4ms
# image 48/102 /content/datasets/Object-Detection-URC-4/test/images/20231031_222758_jpg.rf.9818289463dab0b3d1892bb9e56e814f.jpg: 800x800 (no detections), 11.4ms
# image 49/102 /content/datasets/Object-Detection-URC-4/test/images/20231031_222828_jpg.rf.ae219cd1faa5bec7b238ef45100e5a79.jpg: 800x800 (no detections), 11.5ms
# image 50/102 /content/datasets/Object-Detection-URC-4/test/images/210_jpg.rf.3fd639eaa3d4e0615994dbc5d1c7e8f7.jpg: 800x800 1 Bottle, 11.4ms
# image 51/102 /content/datasets/Object-Detection-URC-4/test/images/214_jpg.rf.5e535110dfe3c4c8f7499ce28fb0d8b9.jpg: 800x800 1 Bottle, 11.3ms
# image 52/102 /content/datasets/Object-Detection-URC-4/test/images/218_jpg.rf.8ac16759111bdb553367a08c25183118.jpg: 800x800 1 Bottle, 11.2ms
# image 53/102 /content/datasets/Object-Detection-URC-4/test/images/218_jpg.rf.ce692b4aae43d5bfb10e372579863055.jpg: 800x800 1 Bottle, 11.2ms
# image 54/102 /content/datasets/Object-Detection-URC-4/test/images/221_jpg.rf.3f771e68126d3f32412a9103a8290259.jpg: 800x800 1 Bottle, 11.1ms
# image 55/102 /content/datasets/Object-Detection-URC-4/test/images/235_jpg.rf.b20b8b7273f5d75c1066928efb377339.jpg: 800x800 1 Bottle, 11.1ms
# image 56/102 /content/datasets/Object-Detection-URC-4/test/images/24_jpg.rf.950bf06a7b62fa5624ec0d1b163955ee.jpg: 800x800 1 Bottle, 11.1ms
# image 57/102 /content/datasets/Object-Detection-URC-4/test/images/252_jpg.rf.fc495e0ca583d2e4407ad133ab7ea8e1.jpg: 800x800 1 Bottle, 11.1ms
# image 58/102 /content/datasets/Object-Detection-URC-4/test/images/254_jpg.rf.ce8849bb98c38df4655f653b9ccb0443.jpg: 800x800 1 Bottle, 11.1ms
# image 59/102 /content/datasets/Object-Detection-URC-4/test/images/254_jpg.rf.ea6a4453353e2aac83a62c3473a5677a.jpg: 800x800 1 Bottle, 11.1ms
# image 60/102 /content/datasets/Object-Detection-URC-4/test/images/255_jpg.rf.f676209142bf57380a95b3e68eb83f6c.jpg: 800x800 1 Bottle, 11.1ms
# image 61/102 /content/datasets/Object-Detection-URC-4/test/images/260_jpg.rf.e3bc8e59fad9b7c92d63b2a3133af11c.jpg: 800x800 1 Bottle, 11.1ms
# image 62/102 /content/datasets/Object-Detection-URC-4/test/images/265_jpg.rf.5c00acce5de008bd1279ee93cded1283.jpg: 800x800 1 Bottle, 11.4ms
# image 63/102 /content/datasets/Object-Detection-URC-4/test/images/268_jpg.rf.227cc83f6b29267d356433bd7d9ac4df.jpg: 800x800 1 Bottle, 11.5ms
# image 64/102 /content/datasets/Object-Detection-URC-4/test/images/271_jpg.rf.2e1db3809af5be249defdaecad9ae17c.jpg: 800x800 2 Bottles, 11.9ms
# image 65/102 /content/datasets/Object-Detection-URC-4/test/images/274_jpg.rf.af3288cc50af0107e604661005a82e1d.jpg: 800x800 1 Bottle, 11.9ms
# image 66/102 /content/datasets/Object-Detection-URC-4/test/images/34_jpg.rf.df2ef618eeaf9fda9b6412111ef6c73c.jpg: 800x800 1 Bottle, 11.8ms
# image 67/102 /content/datasets/Object-Detection-URC-4/test/images/35_jpg.rf.f50453c54c32aff67f2b422805117a2c.jpg: 800x800 1 Bottle, 11.6ms
# image 68/102 /content/datasets/Object-Detection-URC-4/test/images/46_jpg.rf.bb8ebf4df53176f82a2d6a929a43a850.jpg: 800x800 1 Bottle, 11.4ms
# image 69/102 /content/datasets/Object-Detection-URC-4/test/images/47_jpg.rf.437fea0629c1e31b383ebc186db30b73.jpg: 800x800 1 Bottle, 11.3ms
# image 70/102 /content/datasets/Object-Detection-URC-4/test/images/50_jpg.rf.5973ecd91b47a423f02eb5661e1da859.jpg: 800x800 1 Bottle, 11.2ms
# image 71/102 /content/datasets/Object-Detection-URC-4/test/images/53_jpg.rf.b8e6b31dc0adbee6af09cab100c81a39.jpg: 800x800 1 Bottle, 11.1ms
# image 72/102 /content/datasets/Object-Detection-URC-4/test/images/68_jpg.rf.857d9f50d0d05e8dff7222fb703fa44e.jpg: 800x800 1 Bottle, 11.6ms
# image 73/102 /content/datasets/Object-Detection-URC-4/test/images/69_jpg.rf.79fac9c4b6342fa9f4053194aa92c011.jpg: 800x800 1 Bottle, 11.2ms
# image 74/102 /content/datasets/Object-Detection-URC-4/test/images/70_jpg.rf.257efacd5d27a8261919eef81a48da8c.jpg: 800x800 1 Bottle, 11.1ms
# image 75/102 /content/datasets/Object-Detection-URC-4/test/images/71_jpg.rf.66275f6f08ec70e4288828d40f42f066.jpg: 800x800 1 Bottle, 11.1ms
# image 76/102 /content/datasets/Object-Detection-URC-4/test/images/72_jpg.rf.354ad8025965199dbe8cc7ba17f3ea16.jpg: 800x800 1 Bottle, 11.1ms
# image 77/102 /content/datasets/Object-Detection-URC-4/test/images/73_jpg.rf.d153c19af594644581ccc76d83f4b93e.jpg: 800x800 1 Bottle, 11.1ms
# image 78/102 /content/datasets/Object-Detection-URC-4/test/images/77_jpg.rf.58afe016ed1b46f92d9991f0a8eb916f.jpg: 800x800 1 Bottle, 11.1ms
# image 79/102 /content/datasets/Object-Detection-URC-4/test/images/78_jpg.rf.1e2b7007e7a1748dbb733239d40bc876.jpg: 800x800 1 Bottle, 11.1ms
# image 80/102 /content/datasets/Object-Detection-URC-4/test/images/79_jpg.rf.cd3446c974d93d5b9cf1fa646b01e712.jpg: 800x800 1 Bottle, 11.1ms
# image 81/102 /content/datasets/Object-Detection-URC-4/test/images/7_jpg.rf.b7b769148f790c5444986ca94b0ca38e.jpg: 800x800 1 Bottle, 11.2ms
# image 82/102 /content/datasets/Object-Detection-URC-4/test/images/80_jpg.rf.be30a98b70a98625171809178287b8fb.jpg: 800x800 1 Bottle, 11.9ms
# image 83/102 /content/datasets/Object-Detection-URC-4/test/images/84_jpg.rf.525a17101630b6b4ce6e24ed64d80379.jpg: 800x800 1 Bottle, 11.6ms
# image 84/102 /content/datasets/Object-Detection-URC-4/test/images/88_jpg.rf.003dd88f4108cbb6979a20920d5d9985.jpg: 800x800 1 Bottle, 11.9ms
# image 85/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_2793_JPG_jpg.rf.9ea425ebcdc1df423dffab393af7a81c.jpg: 800x800 1 Bottle, 12.1ms
# image 86/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4472_jpg.rf.5837d2b928b38d73b5600e425685190a.jpg: 800x800 1 Bottle, 12.1ms
# image 87/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4475_jpg.rf.957589f160839ffd84a801064751ea07.jpg: 800x800 1 Bottle, 11.9ms
# image 88/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4482_jpg.rf.9f521eeb86aad0dc0df84213ad63ac7a.jpg: 800x800 1 Bottle, 11.7ms
# image 89/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4484_jpg.rf.f2112251d0abb20bfc8376506eb6e336.jpg: 800x800 1 Bottle, 11.5ms
# image 90/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4487_jpg.rf.be6e55900486b19fa166dcde2eff12f9.jpg: 800x800 1 Bottle, 11.3ms
# image 91/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4488_jpg.rf.f228d1285616e6f9ce007e1eabf0d4b0.jpg: 800x800 1 Bottle, 11.2ms
# image 92/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4498_jpg.rf.a32d35fec9f34a3433284ed93d8e220e.jpg: 800x800 1 Bottle, 11.1ms
# image 93/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4502_jpg.rf.839593bb8351fda3d05bca5340ee52ab.jpg: 800x800 1 Bottle, 11.1ms
# image 94/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4504_jpg.rf.3df028e00d58147bfd6ae6158ccbee26.jpg: 800x800 1 Bottle, 11.1ms
# image 95/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4518_jpg.rf.f1dd544fe68f1e2013b2779eb351879b.jpg: 800x800 1 Bottle, 11.1ms
# image 96/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4519_jpg.rf.f5ee879bf34254a88193c878e8df0fd9.jpg: 800x800 1 Bottle, 11.1ms
# image 97/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4533_jpg.rf.88ee8c6ce7f5d9cb94e6cfa6bd9cbb71.jpg: 800x800 1 Bottle, 11.1ms
# image 98/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4535_jpg.rf.cbd0b546c0be5d13ef0c42de8bd56b93.jpg: 800x800 1 Bottle, 11.1ms
# image 99/102 /content/datasets/Object-Detection-URC-4/test/images/IMG_4537_jpg.rf.7206248c456b7957c392282c96e0d855.jpg: 800x800 1 Bottle, 11.1ms
# image 100/102 /content/datasets/Object-Detection-URC-4/test/images/black-bottle_png.rf.7f195635dbab9c591df7a441db226bf4.jpg: 800x800 1 Bottle, 11.1ms
# image 101/102 /content/datasets/Object-Detection-URC-4/test/images/grey-bottle_png.rf.05577fbeaa07075d11a9088a5da6c5b3.jpg: 800x800 1 Bottle, 11.1ms
# image 102/102 /content/datasets/Object-Detection-URC-4/test/images/small-bottle_png.rf.68697834cfbce26aa9ff00e52de108fe.jpg: 800x800 1 Bottle, 11.1ms
# Speed: 3.9ms preprocess, 12.5ms inference, 6.3ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train2/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/object-detection-ctnhg/object-detection-urc-ds9co/4
# Share your model with the world at: https://universe.roboflow.com/object-detection-ctnhg/object-detection-urc-ds9co/model/4

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on IMG_4482_jpg.rf.9f521eeb86aad0dc0df84213ad63ac7a.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-3a7509f3f341> in <cell line: 0>()
#      10 print("running inference on " + random_test_image)
#      11
# ---> 12 pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
#      13 pred
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
